# %%
import imghdr
import os
import requests
import json
import requests
collect=[]
for i in range(1,20):
        cookies = {
            'xp-search-synonym': 'control',
            'require_cookie_consent': 'false',
            '_ga': 'GA1.1.1197051588.1690879264',
            'azk-ss': 'true',
            'uuid': '04a0ffb0-3049-11ee-9788-297e0b8f733a',
            'xp-search-synonym-replica': 'control',
            'xp-in-feed-direct-ads-refreshed': 'control',
            '_sp_ses.0295': '*',
            'lux_uid': '169124798280635925',
            '_sp_id.0295': 'a1500532-a2f0-4715-ab68-6601313d952b.1690879264.2.1691248026.1690880327.4e7f9457-5633-4aae-85f8-bf02f3c27c87.14fe903d-932c-47a4-aa6c-cd2ce2eb733e.470f40f2-5fa1-4d4a-bdb8-b07acf19a246.1691247981517.13',
            '_ga_21SLH4J369': 'GS1.1.1691247981.2.1.1691248025.0.0.0',
        }

        headers = {
            'authority': 'unsplash.com',
            'accept': '*/*',
            'accept-language': 'en-US',
            'cache-control': 'no-cache',
            # 'cookie': 'xp-search-synonym=control; require_cookie_consent=false; _ga=GA1.1.1197051588.1690879264; azk-ss=true; uuid=04a0ffb0-3049-11ee-9788-297e0b8f733a; xp-search-synonym-replica=control; xp-in-feed-direct-ads-refreshed=control; _sp_ses.0295=*; lux_uid=169124798280635925; _sp_id.0295=a1500532-a2f0-4715-ab68-6601313d952b.1690879264.2.1691248026.1690880327.4e7f9457-5633-4aae-85f8-bf02f3c27c87.14fe903d-932c-47a4-aa6c-cd2ce2eb733e.470f40f2-5fa1-4d4a-bdb8-b07acf19a246.1691247981517.13; _ga_21SLH4J369=GS1.1.1691247981.2.1.1691248025.0.0.0',
            'dnt': '1',
            'pragma': 'no-cache',
            'referer': 'https://unsplash.com/images/stock',
            'sec-ch-ua': '"Not/A)Brand";v="99", "Google Chrome";v="115", "Chromium";v="115"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
            'sec-fetch-dest': 'empty',
            'sec-fetch-mode': 'cors',
            'sec-fetch-site': 'same-origin',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36',
        }

        params = {
            'page': f'{i}',
            'per_page': '20',
            'xp': 'search-synonym-replica:control',
        }

        response = requests.get('https://unsplash.com/napi/landing_pages/images/stock', params=params, cookies=cookies, headers=headers)
        data=response.json()
        collect.append(data)
# collected the json data of 20 sub pages of unsplash
# ************************collecting the url of each iamges*********************************************
urls=[]
for i in range(0,14):
    for j in range(0,20):
        url=collect[i]['photos'][j]['urls']['full']
        urls.append(url)     
# ***************************creating a path to save the downloaded images************************************
path=r"C:\Users\ankit\Py-world\pandas\downloaded_images"
# ********************************visiting each image and save it to the folder********************************
for i, link in enumerate(urls):
    r=requests.get(link)
    try:
        if(r.status_code==200):
            image_format=imghdr.what(None,r.content)
            file=f"downloaded_image_{i}.{image_format}"
            file_path=os.path.join(path,file)
#             saving the downloaded images in the speific location
            try: 
                if image_format:
                    with open(file_path,'wb') as file:
                        file.write(r.content)
                else:
                    print('error determining the format of the image')
            except Exception as e:
                print("error determining the format")
        else:
            print("status failed")
    except Exception as e:
        print(e)
print('success')
